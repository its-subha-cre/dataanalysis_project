# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel('Customer Call List.xlsx')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.shape
# Out:
# (21, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         21 non-null     int64
#  1   First_Name         21 non-null     object
#  2   Last_Name          20 non-null     object
#  3   Phone_Number       19 non-null     object
#  4   Address            21 non-null     object
#  5   Paying Customer    21 non-null     object
#  6   Do_Not_Contact     17 non-null     object
#  7   Not_Useful_Column  21 non-null     bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 1.3+ KB

# %%
type(df.Address[0])
# Out:
# str

# %%
df.iloc[0].Address
# Out:
# '123 Shire Lane, Shire'

# %%
df.loc[0,"Address"]
# Out:
# '123 Shire Lane, Shire'

# %%
df['Full_Name']=df['First_Name']+' '+df['Last_Name']

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Full_Name'].str.replace('A',' ')
# Out:
# 0        Frodo Baggins
# 1            bed Nadir
# 2        Walter /White
# 3       Dwight Schrute
# 4             Jon Snow
# 5          Ron Swanson
# 6        Jeff   Winger
# 7      Sherlock Holmes
# 8                  NaN
# 9         Peter Parker
# 10      Samwise Gamgee
# 11     Harry ...Potter
# 12          Don Draper
# 13        Leslie Knope
# 14    Toby Flenderson_
# 15         Ron Weasley
# 16      Michael  Scott
# 17          Clark Kent
# 18        Creed Braton
# 19     nakin Skywalker
# 20     nakin Skywalker
# Name: Full_Name, dtype: object

# %%
df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Full_Name']=df['First_Name']+' '+df['Last_Name']
for i in df.index:
    if df.iloc[i].Full_Name == 'Jon Snow':
        df.drop(i,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 df['Full_Name']=df['First_Name']+' '+df['Last_Name']
#       2 for i in df.index:
# ----> 3     if df.iloc[i].Full_Name == 'Jon Snow':
#       4         df.drop(i,inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# ...

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# ...

# %%
# df['Last_Name']=df['Last_Name'].str.lstrip('...')
# df['Last_Name']=df['Last_Name'].str.rstrip()
df['Last_Name']=df['Last_Name'].str.strip("123._/")

# %%
df

# %%
df.dropna()

# %% [markdown]
# df['Phone_Number']=df['Phone_Number'].str.strip("123._/")

# %% [raw]
# df

# %%
df['Address']
# Out:
# 0                     123 Shire Lane, Shire
# 1                       93 West Main Street
# 2                        298 Drugs Driveway
# 3     980 Paper Avenue, Pennsylvania, 18503
# 5                          768 City Parkway
# 6                         1209 South Street
# 7                             98 Clue Drive
# 8                          123 Middle Earth
# 9                25th Main Street, New York
# 10                    612 Shire Lane, Shire
# 11                     2394 Hogwarts Avenue
# 12                         2039 Main Street
# 13                         343 City Parkway
# 14                            214 HR Avenue
# 15                     2395 Hogwarts Avenue
# 16           121 Paper Avenue, Pennsylvania
# 17                          3498 Super Lane
# 18                                      N/a
# 19              910 Tatooine Road, Tatooine
# 20              910 Tatooine Road, Tatooine
# Name: Address, dtype: object

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# ...

# %%
df.fillna('')
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf                        N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# ...

# %%
df['Phone_Number']=df['Phone_Number'].str.replace("-","")
df['Phone_Number']=df['Phone_Number'].str.replace("|","")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    1235455421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute    1235432345
# 5         1006        Ron      Swanson    3047622467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes    8766783469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker    1235455421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper    1235432345
# 13        1014     Leslie        Knope    8766783469
# 14        1015       Toby  Flenderson_    3047622467
# 15        1016        Ron      Weasley    1235455421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent           NaN
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    1235455421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute    1235432345
# 5         1006        Ron      Swanson    3047622467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes    8766783469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker    1235455421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper    1235432345
# 13        1014     Leslie        Knope    8766783469
# 14        1015       Toby  Flenderson_    3047622467
# 15        1016        Ron      Weasley    1235455421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent           NaN
# ...

# %%
df["Address"]=df["Address"].str.split(',')

# %%
df.shape
# Out:
# (13, 15)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    1235455421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1004     Dwight      Schrute    1235432345
# 3         1006        Ron      Swanson    3047622467
# 4         1008   Sherlock       Holmes    8766783469
# 5         1010      Peter       Parker    1235455421
# 6         1013        Don       Draper    1235432345
# 7         1014     Leslie        Knope    8766783469
# 8         1015       Toby  Flenderson_    3047622467
# 9         1016        Ron      Weasley    1235455421
# 10        1017   Michael         Scott  123/643/9775
# 11        1019      Creed       Braton           N/a
# 12        1020     Anakin    Skywalker    8766783469
#
#                                               Address Paying Customer  \
# 0   [1 ,    ,  2 ,    ,  3 ,    ,    ,    ,  S ,  ...             Yes
# 1   [9 ,    ,  3 ,    ,    ,    ,  W ,    ,  e ,  ...              No
# ...

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    1235455421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1004     Dwight      Schrute    1235432345
# 3         1006        Ron      Swanson    3047622467
# 4         1008   Sherlock       Holmes    8766783469
# 5         1010      Peter       Parker    1235455421
# 6         1013        Don       Draper    1235432345
# 7         1014     Leslie        Knope    8766783469
# 8         1015       Toby  Flenderson_    3047622467
# 9         1016        Ron      Weasley    1235455421
# 10        1017   Michael         Scott  123/643/9775
# 11        1019      Creed       Braton           N/a
# 12        1020     Anakin    Skywalker    8766783469
#
#                                               Address Paying Customer  \
# 0   [1 ,    ,  2 ,    ,  3 ,    ,    ,    ,  S ,  ...             Yes
# 1   [9 ,    ,  3 ,    ,    ,    ,  W ,    ,  e ,  ...              No
# ...

# %%
df.shape
# Out:
# (13, 16)

# %%
df.reset_index(drop=True)
# Out:
#     index  CustomerID First_Name    Last_Name  Phone_Number  \
# 0       0        1001      Frodo      Baggins    1235455421
# 1       1        1002       Abed        Nadir  123/643/9775
# 2       3        1004     Dwight      Schrute    1235432345
# 3       5        1006        Ron      Swanson    3047622467
# 4       7        1008   Sherlock       Holmes    8766783469
# 5       9        1010      Peter       Parker    1235455421
# 6      12        1013        Don       Draper    1235432345
# 7      13        1014     Leslie        Knope    8766783469
# 8      14        1015       Toby  Flenderson_    3047622467
# 9      15        1016        Ron      Weasley    1235455421
# 10     16        1017   Michael         Scott  123/643/9775
# 11     18        1019      Creed       Braton           N/a
# 12     19        1020     Anakin    Skywalker    8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# ...

# %%
import ast

# %%
def pass1(obj):
    return " ".join(obj)
df["Address"]=df["Address"].apply(pass1)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    1235455421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1004     Dwight      Schrute    1235432345
# 3         1006        Ron      Swanson    3047622467
# 4         1008   Sherlock       Holmes    8766783469
# 5         1010      Peter       Parker    1235455421
# 6         1013        Don       Draper    1235432345
# 7         1014     Leslie        Knope    8766783469
# 8         1015       Toby  Flenderson_    3047622467
# 9         1016        Ron      Weasley    1235455421
# 10        1017   Michael         Scott  123/643/9775
# 11        1019      Creed       Braton           N/a
# 12        1020     Anakin    Skywalker    8766783469
#
#                                               Address Paying Customer  \
# 0   1 ,   , 2 ,   , 3 ,   ,   ,   , S ,   , h ,   ...             Yes
# 1   9 ,   , 3 ,   ,   ,   , W ,   , e ,   , s ,   ...              No
# ...

# %%
df.Address.str.split(',',n=2,expand=True)
# Out:
#      0
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 12 NaN

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    1235455421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1004     Dwight      Schrute    1235432345
# 3         1006        Ron      Swanson    3047622467
# 4         1008   Sherlock       Holmes    8766783469
# 5         1010      Peter       Parker    1235455421
# 6         1013        Don       Draper    1235432345
# 7         1014     Leslie        Knope    8766783469
# 8         1015       Toby  Flenderson_    3047622467
# 9         1016        Ron      Weasley    1235455421
# 10        1017   Michael         Scott  123/643/9775
# 11        1019      Creed       Braton           N/a
# 12        1020     Anakin    Skywalker    8766783469
#
#                                               Address Paying Customer  \
# 0   1 ,   , 2 ,   , 3 ,   ,   ,   , S ,   , h ,   ...             Yes
# 1   9 ,   , 3 ,   ,   ,   , W ,   , e ,   , s ,   ...              No
# ...

# %%
df.reset_index(drop=True)
# Out:
#     index  CustomerID First_Name    Last_Name  Phone_Number  \
# 0       0        1001      Frodo      Baggins    1235455421
# 1       1        1002       Abed        Nadir  123/643/9775
# 2       3        1004     Dwight      Schrute    1235432345
# 3       5        1006        Ron      Swanson    3047622467
# 4       7        1008   Sherlock       Holmes    8766783469
# 5       9        1010      Peter       Parker    1235455421
# 6      12        1013        Don       Draper    1235432345
# 7      13        1014     Leslie        Knope    8766783469
# 8      14        1015       Toby  Flenderson_    3047622467
# 9      15        1016        Ron      Weasley    1235455421
# 10     16        1017   Michael         Scott  123/643/9775
# 11     18        1019      Creed       Braton           N/a
# 12     19        1020     Anakin    Skywalker    8766783469
#
#                                               Address Paying Customer  \
# ...

# %%
df=df.drop(columns="index")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins    1235455421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1004     Dwight      Schrute    1235432345
# 3         1006        Ron      Swanson    3047622467
# 4         1008   Sherlock       Holmes    8766783469
# 5         1010      Peter       Parker    1235455421
# 6         1013        Don       Draper    1235432345
# 7         1014     Leslie        Knope    8766783469
# 8         1015       Toby  Flenderson_    3047622467
# 9         1016        Ron      Weasley    1235455421
# 10        1017   Michael         Scott  123/643/9775
# 11        1019      Creed       Braton           N/a
# 12        1020     Anakin    Skywalker    8766783469
#
#                                               Address Paying Customer  \
# 0           1 2 3   S h i r e   L a n e     S h i r e             Yes
# 1               9 3   W e s t   M a i n   S t r e e t              No
# ...

# %%
df.drop(columns=["first","Last","adress","First_Name","Last_Name"],inplace=True)

# %%
df["Phone_Number"]=df['Phone_Number'].str.replace("N/a"," ")

# %%
df
# Out:
#     CustomerID  Phone_Number  \
# 0         1001    1235455421
# 1         1002  123/643/9775
# 2         1004    1235432345
# 3         1006    3047622467
# 4         1008    8766783469
# 5         1010    1235455421
# 6         1013    1235432345
# 7         1014    8766783469
# 8         1015    3047622467
# 9         1016    1235455421
# 10        1017  123/643/9775
# 11        1019
# 12        1020    8766783469
#
#                                               Address Paying Customer  \
# 0   [1 ,    ,  2 ,    ,  3 ,    ,    ,    ,  S ,  ...             Yes
# 1   [9 ,    ,  3 ,    ,    ,    ,  W ,    ,  e ,  ...              No
# 2   [9 ,    ,  8 ,    ,  0 ,    ,    ,    ,  P ,  ...             Yes
# 3   [7 ,    ,  6 ,    ,  8 ,    ,    ,    ,  C ,  ...             Yes
# 4   [9 ,    ,  8 ,    ,    ,    ,  C ,    ,  l ,  ...               N
# 5   [2 ,    ,  5 ,    ,  t ,    ,  h ,    ,    ,  ...             Yes
# ...
